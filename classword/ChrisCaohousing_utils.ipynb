# %%
# 1. First 5 columns
housing_full.iloc[:, :5].head()

# 2. Only columns total_rooms and total_bedrooms
housing_full[["total_rooms", "total_bedrooms"]].head()

# 3. Only rows with population > 1000
housing_full[housing_full["population"] > 1000].head()

# 4. Those columns AND those rows
housing_full.loc[housing_full["population"] > 1000, ["total_rooms", "total_bedrooms"]].head()

# 5. Alternate rows using np.arange()
housing_full.iloc[np.arange(0, len(housing_full), 2)].head()
